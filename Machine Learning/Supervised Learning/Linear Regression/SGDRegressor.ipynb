# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, mean_absolute_percentage_error

# %%
df = pd.read_csv('tvmarketing.csv')

# %%
df.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
x = df['TV'].values.reshape(-1, 1)
y = df['Sales'].values.reshape(-1, 1)

# %%
robust = RobustScaler()

# %%
robust_x = robust
robust_y = robust

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = .7, test_size = .3)

# %%
x_train_scaler = robust_x.fit_transform(x_train)
x_test_scaler = robust.transform(x_test)
y_train_scaler = robust_y.fit_transform(y_train)
y_test_scaler = robust.transform(y_test)

# %%
sgd = SGDRegressor()

# %%
model = sgd.fit(x_train_scaler, y_train_scaler)
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_pred = model.predict(x_test_scaler)

# %%
def mae(y_pred, y_test):
    return mean_absolute_error(y_pred, y_test)

def rmse(y_pred, y_test):
    return root_mean_squared_error(y_pred, y_test)

def mape(y_pred, y_test):
    return mean_absolute_percentage_error(y_pred, y_test)

# %%
print('MAE:', mae(y_pred, y_test_scaler))
print('RMSE:', rmse(y_pred, y_test_scaler))
print('MAPE:', mape(y_pred, y_test_scaler))
# Out:
# MAE: 0.4062150009046857
# RMSE: 0.49936521951460866
# MAPE: 12.879308753508385
